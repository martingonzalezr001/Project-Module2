# %%
import pandas as pd

# %%
my_df = pd.read_csv('..\data\datamadpt_0924 - martin.csv')

# %%
my_df
# Out:
#                                    1. Teams                        Unnamed: 1  \
# 0    Stores information about soccer teams.                               NaN
# 1                                       NaN                               NaN
# 2                                Field Name                           Meaning
# 3                                    TeamID   Unique identifier for the team.
# 4                                  TeamName          Name of the soccer team.
# ..                                      ...                               ...
# 99                               Field Name                           Meaning
# 100                                 VenueID  Unique identifier for the venue.
# 101                               VenueName                Name of the venue.
# 102                                    City  City where the venue is located.
# 103                                Capacity    Seating capacity of the venue.
#
#                             Unnamed: 2
# 0                                  NaN
# 1                                  NaN
# 2                              Example
# 3                           1, 2, 2003
# 4     Manchester United, "Real Madrid"
# ..                                 ...
# 99                             Example
# 100                      301, 302, 303
# 101  Old Trafford, "Santiago Bernabeu"
# 102               Manchester, "Madrid"
# 103                       75000, 81000
#
# [104 rows x 3 columns]

# %%
df_teams = pd.read_csv('..\data\mis_datos\Teams_Table.csv')
df_players = pd.read_csv('..\data\mis_datos\Players_Table.csv')
df_matches = pd.read_csv('..\data\mis_datos\Matches_Table.csv')
df_events = pd.read_csv('..\data\mis_datos\Events_Table.csv')
df_goals = pd.read_csv('..\data\mis_datos\Goals_Table.csv')
df_assists = pd.read_csv('..\data\mis_datos\Assists_Table.csv')
df_tournaments = pd.read_csv('..\data\mis_datos\Tournaments_Table.csv')
df_venues = pd.read_csv('..\data\mis_datos\Venues_Table.csv')
df_player_stats = pd.read_csv('..\data\mis_datos\PlayerStats_Table.csv')
df_team_stats = pd.read_csv('..\data\mis_datos\TeamStats_Table.csv')

# %% [markdown]
# ## TEAMS TABLE

# %%
df_teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TeamID       40 non-null     int64
#  1   TeamName     40 non-null     object
#  2   CoachName    40 non-null     object
#  3   Country      40 non-null     object
#  4   FoundedYear  40 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 1.7+ KB

# %%
df_teams["TeamID"].nunique()
# Out:
# 40

# %%
df_teams["TeamName"].nunique()
# Out:
# 40

# %%
df_teams.head(20)
# Out:
#     TeamID                     TeamName              CoachName Country  \
# 0        1               Fitzgerald PLC  Mr. James Mcbride DDS   Spain
# 1        2                Lane and Sons      Jennifer Mccarthy   Spain
# 2        3               Bryant-Holland         Deborah Garcia   Spain
# 3        4  Thomas, Sandoval and Gibson         Brandon Molina   Spain
# 4        5                    White-Fry         William Gaines   Spain
# 5        6                   Prince PLC            Karen Casey   Spain
# 6        7  Miller, Carpenter and Adams         Sherry Schmidt   Spain
# 7        8                 Matthews Inc          Robert Hurley   Spain
# 8        9         Harris, Yu and Vance           Taylor Scott   Spain
# 9       10                   Walker Ltd             Laura Kent   Spain
# 10      11     Cain, Manning and Miller       Jennifer Shannon   Spain
# 11      12                Cook and Sons         Shawn Buchanan   Spain
# 12      13    Williams, Burke and Moore             Sarah Wall   Spain
# 13      14                  Dunn-Rogers         Michael Nelson   Spain
# 14      15    Henry, Smith and Robinson         Dwayne Estrada   Spain
# 15      16             Raymond-Reynolds             Cody Olson   Spain
# 16      17    Monroe, Dalton and Brooks          Scott Griffin   Spain
# 17      18       Payne, Kemp and Jordan       Timothy Castillo   Spain
# 18      19             Castillo-Freeman        Barbara Simpson   Spain
# 19      20                    Mcgee Ltd    Dr. Spencer Huffman   Spain
#
#     FoundedYear
# 0          1891
# 1          1986
# 2          1944
# 3          1965
# 4          1980
# 5          1939
# 6          1921
# 7          2016
# 8          1959
# 9          1972
# 10         1970
# 11         1891
# 12         1921
# 13         1923
# 14         1998
# 15         1899
# 16         2015
# 17         1925
# 18         1950
# 19         1944

# %% [markdown]
# ## PLAYERS TABLE

# %%
df_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PlayerID     920 non-null    int64
#  1   PlayerName   920 non-null    object
#  2   TeamID       920 non-null    int64
#  3   Position     920 non-null    object
#  4   BirthDate    920 non-null    object
#  5   Nationality  920 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 43.2+ KB

# %%
df_players["PlayerID"].nunique()
# Out:
# 920

# %%
df_players["PlayerName"].nunique()
# Out:
# 916

# %%
df_players["TeamID"].nunique()
# Out:
# 40

# %%
df_players.head(20)
# Out:
#     PlayerID          PlayerName  TeamID    Position   BirthDate  \
# 0          1     Steven Chambers       1    Defender  1987-07-02
# 1          2        Barry Wilson       1  Goalkeeper  1996-02-23
# 2          3      Andrew Esparza       1  Goalkeeper  1993-10-23
# 3          4        Tiffany Lane       1    Defender  2003-04-29
# 4          5      Linda Williams       1  Midfielder  2005-11-17
# 5          6    Erika Strickland       1     Forward  2001-12-08
# 6          7     Larry Rodriguez       1  Goalkeeper  2005-12-13
# 7          8      Tamara Mcclure       1  Midfielder  1986-01-11
# 8          9     Phillip Johnson       1    Defender  1998-04-12
# 9         10         Ryan Melton       1    Defender  1998-05-15
# 10        11        Maria Booker       1    Defender  1994-08-05
# 11        12  Catherine Crawford       1  Midfielder  2000-01-19
# 12        13       Zachary Patel       1     Forward  1994-05-13
# 13        14   Zachary Schneider       1  Midfielder  2000-07-18
# 14        15        Brad Montoya       1    Defender  1991-09-03
# 15        16        Casey Bowers       1     Forward  1996-01-13
# 16        17      Danielle Young       1  Midfielder  1987-04-11
# 17        18      Elizabeth Sims       1  Midfielder  1990-03-13
# 18        19    Samantha Brennan       1     Forward  1991-10-26
# 19        20       Brandon Ewing       1  Goalkeeper  2001-03-10
#
#                                           Nationality
# 0                                   Wallis and Futuna
# 1                                           Australia
# 2                                             Estonia
# 3                                            Dominica
# 4                                          Montenegro
# 5                                               Italy
# 6                                       Liechtenstein
# 7                                             Lebanon
# 8                                             Albania
# 9                                         Afghanistan
# 10                             Bosnia and Herzegovina
# 11                                  Brunei Darussalam
# 12  British Indian Ocean Territory (Chagos Archipe...
# 13                                             Belize
# 14                                      French Guiana
# 15                                             Guyana
# 16                                             Poland
# 17                                              Korea
# 18                                         Costa Rica
# 19                                            Lebanon

# %% [markdown]
# ## MATCHES TABLE

# %%
df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MatchID       2500 non-null   int64
#  1   TournamentID  2500 non-null   int64
#  2   VenueID       2500 non-null   int64
#  3   Date          2500 non-null   object
#  4   HomeTeamID    2500 non-null   int64
#  5   AwayTeamID    2500 non-null   int64
#  6   FinalScore    2500 non-null   object
# dtypes: int64(5), object(2)
# memory usage: 136.8+ KB

# %%
df_matches["MatchID"].nunique()
# Out:
# 2500

# %%
df_matches["TournamentID"].nunique()
# Out:
# 5

# %%
df_matches["VenueID"].nunique()
# Out:
# 40

# %%
df_matches.head(20)
# Out:
#     MatchID  TournamentID  VenueID        Date  HomeTeamID  AwayTeamID  \
# 0         1             1       11  2024-09-30          13          10
# 1         2             1       15  2024-09-19           3           6
# 2         3             1        5  2024-07-24          17           1
# 3         4             1        4  2024-05-26          18          20
# 4         5             1       28  2024-08-12          14          17
# 5         6             1       10  2024-09-25          11          10
# 6         7             1        4  2024-06-20           4           1
# 7         8             1        8  2024-07-21          19           2
# 8         9             1       39  2024-09-10          10          13
# 9        10             1       33  2024-09-08          13           4
# 10       11             1       17  2024-09-14          11           2
# 11       12             1        8  2024-10-06           2          13
# 12       13             1       18  2024-12-26          14           1
# 13       14             1       23  2024-09-27          17           3
# 14       15             1       14  2024-07-23          14           2
# 15       16             1       12  2024-10-24          20           8
# 16       17             1       30  2024-11-21          18          20
# 17       18             1        3  2024-07-02           4          11
# 18       19             1       19  2024-06-28           6           8
# 19       20             1       22  2024-11-19          13          10
#
#    FinalScore
# 0         3-5
# 1         4-3
# 2         1-5
# 3         2-2
# 4         4-3
# 5         1-3
# 6         2-3
# 7         0-1
# 8         1-2
# 9         2-3
# 10        4-5
# 11        5-3
# 12        4-3
# 13        5-4
# 14        1-3
# 15        2-2
# 16        5-0
# 17        3-2
# 18        5-4
# 19        3-2

# %% [markdown]
# ## EVENTS TABLE

# %%
df_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   EventID    25000 non-null  int64
#  1   MatchID    25000 non-null  int64
#  2   PlayerID   25000 non-null  int64
#  3   EventType  25000 non-null  object
#  4   Minute     25000 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 976.7+ KB

# %%
df_events["EventID"].nunique()
# Out:
# 25000

# %%
df_events["MatchID"].nunique()
# Out:
# 2500

# %%
df_events["PlayerID"].nunique()
# Out:
# 920

# %%
df_events["EventType"].nunique()
# Out:
# 5

# %%
df_events.head(20)
# Out:
#     EventID  MatchID  PlayerID     EventType  Minute
# 0         1     1108       817  Substitution      33
# 1         2      392       509       Offside      62
# 2         3     2040       606       Offside      13
# 3         4     1073       164  Substitution      84
# 4         5      312       250       Offside      19
# 5         6     1950       877       Offside      12
# 6         7     1198       815       Offside      25
# 7         8     1830       859       Offside      35
# 8         9      287       568        Injury       4
# 9        10      528       142   Yellow Card      38
# 10       11       73       425  Substitution      25
# 11       12     1491       578   Yellow Card      28
# 12       13      169       353  Substitution      82
# 13       14     1466       865  Substitution      25
# 14       15     1417       715      Red Card      32
# 15       16      296       640      Red Card      35
# 16       17     2069       658       Offside      89
# 17       18      628       625       Offside       5
# 18       19     1808       463       Offside      88
# 19       20     2026       684       Offside      56

# %% [markdown]
# ## GOALS TABLE

# %%
df_goals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   GoalID    7500 non-null   int64
#  1   MatchID   7500 non-null   int64
#  2   PlayerID  7500 non-null   int64
#  3   TeamID    7500 non-null   int64
#  4   Minute    7500 non-null   int64
# dtypes: int64(5)
# memory usage: 293.1 KB

# %%
df_goals["GoalID"].nunique()
# Out:
# 7500

# %%
df_goals["MatchID"].nunique()
# Out:
# 2364

# %%
df_goals["PlayerID"].nunique()
# Out:
# 920

# %%
df_goals["TeamID"].nunique()
# Out:
# 40

# %%
df_goals.head(20)
# Out:
#     GoalID  MatchID  PlayerID  TeamID  Minute
# 0        1      583       325       1      39
# 1        2     2356       327      20      86
# 2        3      165       182      13       8
# 3        4      164       432      27      87
# 4        5     1364        80      15      45
# 5        6     2499       210       5      14
# 6        7      618       361      28      21
# 7        8     1461       705      23      61
# 8        9     1207       643      38      37
# 9       10     2029       288       3      66
# 10      11     2087        88      14      25
# 11      12     1516       130      36      59
# 12      13     1222       550      19      55
# 13      14     1322       475      14      67
# 14      15     1428       590       3      20
# 15      16     2312       696       9      70
# 16      17     2076       834      30      56
# 17      18     1044       575      17      57
# 18      19      178       171      17      29
# 19      20      994       402      20      10

# %% [markdown]
# ## ASSISTS TABLE

# %%
df_assists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   AssistID  7500 non-null   int64
#  1   MatchID   7500 non-null   int64
#  2   PlayerID  7500 non-null   int64
#  3   TeamID    7500 non-null   int64
#  4   Minute    7500 non-null   int64
# dtypes: int64(5)
# memory usage: 293.1 KB

# %%
df_assists["AssistID"].nunique()
# Out:
# 7500

# %%
partidos = df_assists["MatchID"].unique()

# %%
jugadores_asistentes = df_assists["PlayerID"].unique()

# %%
print(len(jugadores_asistentes))
# Out:
# 920

# %%
equipos_asistentes = df_assists["TeamID"].unique()

# %%
print(len(equipos_asistentes))
# Out:
# 40

# %%
df_assists.head(20)
# Out:
#     AssistID  MatchID  PlayerID  TeamID  Minute
# 0          1     1983        83      19      39
# 1          2     1245       176       7      25
# 2          3     1146       234       3      51
# 3          4     1683       571      26       4
# 4          5     1908       316      24      46
# 5          6     1287       831      31       2
# 6          7       21       243      32      60
# 7          8     2331       319      18      39
# 8          9     2389       329       7      29
# 9         10      760       531      11      11
# 10        11     2157       648       4       3
# 11        12      104       570      16      78
# 12        13      869       850      18      83
# 13        14     1722       201      38      81
# 14        15      336       760      21      12
# 15        16     1841       419       1      67
# 16        17     1585       452      15      70
# 17        18     1140       441      15      89
# 18        19     1600       715      25      67
# 19        20     2154       445      40      62

# %% [markdown]
# ## TOURNAMENT TABLE

# %%
df_tournaments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TournamentID       5 non-null      int64
#  1   Name               5 non-null      object
#  2   StartDate          5 non-null      object
#  3   EndDate            5 non-null      object
#  4   CountriesInvolved  5 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 328.0+ bytes

# %%
df_tournaments["TournamentID"].nunique()
# Out:
# 5

# %%
df_tournaments["Name"].nunique()
# Out:
# 5

# %%
df_tournaments.head(20)
# Out:
#    TournamentID                       Name   StartDate     EndDate  \
# 0             1                    La Liga  2023-12-30  2025-09-12
# 1             2               Copa del Rey  2024-11-11  2025-08-08
# 2             3                    Serie A  2024-07-18  2025-11-20
# 3             4               Coppa Italia  2023-06-17  2025-03-28
# 4             5  Spanish-Italian Challenge  2023-05-17  2025-03-21
#
#   CountriesInvolved
# 0             Spain
# 1             Spain
# 2             Italy
# 3             Italy
# 4      Spain, Italy

# %% [markdown]
# ## VENUES TABLE

# %%
df_venues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   VenueID     40 non-null     int64
#  1   VenueName   40 non-null     object
#  2   City        40 non-null     object
#  3   Country     40 non-null     object
#  4   Capacity    40 non-null     int64
#  5   OpenedYear  40 non-null     int64
#  6   GrassType   40 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 2.3+ KB

# %%
df_venues["VenueID"].nunique()
# Out:
# 40

# %%
df_venues["VenueName"].nunique()
# Out:
# 40

# %%
df_venues["VenueName"].head(20)
# Out:
# 0          Kirby, Juarez and Moreno Stadium
# 1                    Osborne-Nelson Stadium
# 2                   Anderson-Wright Stadium
# 3                        Knight LLC Stadium
# 4                        Roy-Torres Stadium
# 5                       Short-Smith Stadium
# 6                   Williams-Franco Stadium
# 7                        Wilson Inc Stadium
# 8                    Long-Gallagher Stadium
# 9            Jones, Brown and Kelly Stadium
# 10                 Johnson and Sons Stadium
# 11                    Hughes-Morris Stadium
# 12                  Higgins-Chapman Stadium
# 13     Taylor, Cabrera and Gonzales Stadium
# 14      Morris, Arellano and Larsen Stadium
# 15                   Duffy-Robinson Stadium
# 16    Nelson, Jacobson and Gonzalez Stadium
# 17                       Thomas PLC Stadium
# 18          Warren, Hill and Church Stadium
# 19       Martinez, Clark and Martin Stadium
# Name: VenueName, dtype: object

# %% [markdown]
# ## PLAYER STATS TABLE

# %%
df_player_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55000 entries, 0 to 54999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StatID         55000 non-null  int64
#  1   MatchID        55000 non-null  int64
#  2   PlayerID       55000 non-null  int64
#  3   MinutesPlayed  55000 non-null  int64
#  4   Goals          55000 non-null  int64
#  5   Assists        55000 non-null  int64
#  6   PassAccuracy   55000 non-null  int64
#  7   ShotsOnTarget  55000 non-null  int64
# dtypes: int64(8)
# memory usage: 3.4 MB

# %%
df_player_stats["StatID"].nunique()
# Out:
# 55000

# %%
df_player_stats["MatchID"].nunique()
# Out:
# 2500

# %%
df_player_stats["PlayerID"].nunique()
# Out:
# 63

# %%
df_player_stats["Goals"]
# Out:
# 0     1
# 1     1
# 2     2
# 3     1
# 4     2
#      ..
# 95    0
# 96    3
# 97    1
# 98    1
# 99    0
# Name: Goals, Length: 100, dtype: int64

# %%
df_player_stats.head(20)
# Out:
#           StatID  MatchID  PlayerID  MinutesPlayed  Goals  Assists  \
# 0    PlayerStat1  Match48  Player62             23      1        1
# 1    PlayerStat2  Match16  Player67              2      1        2
# 2    PlayerStat3  Match67  Player31              0      2        1
# 3    PlayerStat4  Match36  Player17             65      1        0
# 4    PlayerStat5  Match94  Player75             77      2        1
# 5    PlayerStat6   Match4  Player42             81      2        1
# 6    PlayerStat7  Match49  Player94             41      3        2
# 7    PlayerStat8  Match43  Player34             12      1        2
# 8    PlayerStat9  Match43  Player74             71      1        1
# 9   PlayerStat10   Match4  Player32             17      2        2
# 10  PlayerStat11  Match67  Player42             83      1        1
# 11  PlayerStat12  Match42  Player49              5      0        2
# 12  PlayerStat13  Match22  Player96             69      0        0
# 13  PlayerStat14   Match8  Player70             21      1        2
# 14  PlayerStat15  Match91  Player27             36      0        0
# 15  PlayerStat16  Match64  Player73             88      0        2
# 16  PlayerStat17  Match51  Player25             19      3        1
# 17  PlayerStat18  Match56  Player51             12      1        0
# 18  PlayerStat19   Match8  Player22             59      2        1
# 19  PlayerStat20  Match22  Player69             60      0        0
#
#     PassAccuracy  ShotsOnTarget
# 0           61.4              2
# 1           72.6              1
# 2           87.9              2
# 3           82.9              4
# 4           82.2              3
# 5           80.4              1
# 6           84.5              4
# 7           73.3              2
# 8           95.3              2
# 9           57.6              4
# 10          95.6              3
# 11          56.7              5
# 12          59.6              2
# 13          51.1              0
# 14          69.9              2
# 15          99.4              4
# 16          86.2              0
# 17          85.9              4
# 18          75.3              3
# 19          79.5              3

# %% [markdown]
# ## TEAM STATS TABLE

# %%
df_team_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TeamStatID     100 non-null    object
#  1   MatchID        100 non-null    object
#  2   TeamID         100 non-null    object
#  3   Possession     100 non-null    float64
#  4   Shots          100 non-null    int64
#  5   ShotsOnTarget  100 non-null    int64
#  6   Fouls          100 non-null    int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 5.6+ KB

# %%
df_team_stats["TeamStatID"].nunique()
# Out:
# 100

# %%
df_team_stats["TeamID"].nunique()
# Out:
# 66

# %%
df_team_stats["MatchID"].nunique()
# Out:
# 61

# %% [markdown]
# ## Conclusiones:
#  - Ningun id se repite en ninguna tabla (pk)
#  - No hay nulos

# %%
df_team_stats.head(20)
# Out:
#     TeamStatID  MatchID  TeamID  Possession  Shots  ShotsOnTarget  Fouls
# 0    TeamStat1  Match19  Team86        62.5     18             10      6
# 1    TeamStat2  Match25  Team62        58.4     20              5      0
# 2    TeamStat3  Match61  Team72        48.7      6             10      2
# 3    TeamStat4  Match56  Team17        63.6     10              6      3
# 4    TeamStat5  Match19  Team85        45.8      9              4      8
# 5    TeamStat6  Match63  Team20        57.4     19              9     12
# 6    TeamStat7  Match50  Team43        30.4      5              2     11
# 7    TeamStat8  Match53  Team53        40.5     16              2      4
# 8    TeamStat9  Match54   Team4        37.9     16              3      9
# 9   TeamStat10  Match70   Team4        48.4      8              4     10
# 10  TeamStat11  Match65  Team76        48.7     13              3      1
# 11  TeamStat12  Match19  Team50        66.8     10              9      3
# 12  TeamStat13   Match3  Team88        37.9      9              7      5
# 13  TeamStat14  Match90  Team14        44.6     11              2      5
# 14  TeamStat15  Match93  Team99        38.5     17              5      7
# 15  TeamStat16  Match93  Team71        50.0      5              8     14
# 16  TeamStat17  Match98  Team42        56.6     15              1      9
# 17  TeamStat18  Match66  Team90        50.2     11              1     15
# 18  TeamStat19  Match90   Team5        47.9     20              3      0
# 19  TeamStat20  Match10  Team64        37.6     12              5     11
